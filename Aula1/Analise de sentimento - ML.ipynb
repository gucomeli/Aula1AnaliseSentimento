# %% [markdown]
# **Cadastrar acesso a API do Twitter**
#
# https://developer.twitter.com/en/apps

# %%
#Você precisa configurar um aplicativo no Twitter Apps. Depois disso, crie quatro variáveis que armazenarão sua chave e segredo do consumidor e seus tokens
consumer_key = '88PbLPd9PfFpayHSYXWvDVzsN'
consumer_secret = 'W2G4L7AYtxg6TYsVU6INkooP5V2gZzEAZorWMbzfZUsQax6hFN'

access_token = '201376809-LWKPVmRq56RezaycC6Tsefo9Di6fO0UTot1ri4Bj'
access_token_secret = 'F7FPmggTyT2jsrOXUQL4MG3vdS7TmegPu2tqRGGHmynLr'

# %%
#Importar modulos
from textblob import TextBlob as tb #NLP module
import tweepy #Twitter API
import pandas as pd
import numpy as np #para algum cálculo. Você pode querer usar seu módulo favorito para isso, como estatísticas

# %%
#Processo de autenticação
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
#Chama a API
api = tweepy.API(auth)

# %%
#Vamos procurar alguns tweets. Você pode qualquer palavra em inglês
public_tweets = api.search('bolsonaro')

# %%
#Vou usar esta variável mais tarde para algum cálculo
analysis = None

# %%
#Loop para o qual imprimirá cada tweet e sua polaridade de sentimento
#Usamos a função Polarity que é um 
tweets = []
for tweet in public_tweets:
    print(tweet.text)
    analysis = tb(tweet.text)
    polarity = analysis.sentiment.polarity
    tweets.append(polarity)
    print(polarity)
# Out:
# RT @siteptbr: 🚨 Conta oficial da campanha do Bolsonaro TRAVOU após o presidente pedir ajuda por PIX e receber milhares de doações de 1 CENT…
# 0.0
# RT @JosiasCassimir2: Se você continua acreditando na inocência do Lula, prestem atenção nessa matéria. Povo brasileiro, é hora de você pens…
# 0.0
# RT @SergioAJBarrett: E para tentar impedir mais um escândalo, o Bolsonaro colocou 100 anos de sigilo sobre o celular que foi usado pelo ex-…
# 0.0
# RT @UOLNoticias: Depois de mais de 7 meses de investigação, revelamos que 51 dos 107 imóveis do clã Bolsonaro foram pagos em dinheiro vivo…
# 0.0
# RT @saulchristos: O Lula já mandou o TSE remover essa propaganda do Bolsonaro demolindo a mentira de que Lula é inocente.
#
# Mais uma vez, n…
# -0.025
# RT @revistaoeste: Flávio Bolsonaro pede a Aras apreensão de celular de Randolfe Rodrigues https://t.co/4qojWFEXte
# 0.0
# RT @GgmAndrews: 🇧🇷 Governo Bolsonaro jamais cortará a Farmácia Popular 💚
# Não caiam na fake news da esquerda https://t.co/X282njS144
# 0.04999999999999999
# RT @revistaforum: 👉 Bolsonaro coloca sigilo em celular de ex-presidente da Petrobras: mensagens podem incriminá-lo
#
# Leia aqui: https://t.co…
# 0.0
# RT @folha: Eleições 2022: Empresa ligada a site criado para atacar Lula fatura R$ 7 mi de campanha de Bolsonaro e do PL https://t.co/5rVhyy…
# 0.0
# @UOLNoticias Collor e Bolsonaro foi os piores presidentes que o Brasil já teve!
# 0.0
# RT @carapanarana: Tava olhando uns vídeos com comícios do Lula em cidades do interior do Brasil. Volta e meia têm mais gente que aquelas im…
# 0.0
# RT @Jouberth19: Quem acredita na vitória do Bolsonaro no primeiro turno? Eu acredito e vc?✍️🇧🇷#BolsonaroNoPrimeiroTurno22
#
# SIM           SI…
# 0.0
# RT @dinizrnd: Olha só o gesto feito pela repórter da Globo para com os apoiadores do Bolsonaro. Educação, a gente vê por aqui! #GloboLixo h…
# 0.0
# RT @LulaOficial: Bolsonaro pode ficar certo de que o Lulinha paz e amor vai quebrar todos os sigilos que ele fez. #LulaNoRS
# 0.0
# RT @ChristianneS7: Compartilhem a LISTA DOS CANDIDATOS AO SENADO com o Presidente Bolsonaro.
# Vamos eleger bons Candidatos:
# Hamilton Mourão…
# 0.0

# %%
#Depois disso, vamos verificar a média de polaridade de todos os tweets
print('MÉDIA DE SENTIMENTO: ' + str(np.mean(tweets)))
# Out:
# MÉDIA DE SENTIMENTO: 0.001666666666666666
